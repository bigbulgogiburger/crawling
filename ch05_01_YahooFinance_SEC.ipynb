# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt
# Out:
# C:\Users\vuseh\anaconda3\envs\py_finance\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
df = pdr.get_data_yahoo('005930.KS', '2017-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(9,6))
plt.subplot(2,1,1)
plt.title('Samsung Electronic (Yahoo finance)')
plt.plot(df.index,df['Close'],'c',label='Close')
plt.plot(df.index,df['Adj Close'],'b--',label='Adj close')
plt.legend(loc='best')
plt.subplot(2,1,2)
plt.bar(df.index,df['Volume'],color='g',label='Volume')
plt.legend(loc='best')
plt.show()

# %%
from Investar import Analyzer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-ee87b6fce868> in <module>
# ----> 1 from Investar import Analyzer
#
# ModuleNotFoundError: No module named 'Investar'
