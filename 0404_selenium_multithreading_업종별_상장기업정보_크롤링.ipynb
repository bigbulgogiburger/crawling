# %% [markdown]
# ## 증권 종목별 멀티쓰레드를 사용하여 데이터 한번에 다 모으기.
# - author : 편도훈

# %%
from selenium import webdriver
import selenium
import pandas as pd
import numpy as np
import datetime
import time
from tqdm import tqdm
from datetime import datetime

# %% [markdown]
# ## 주소별로 원하는 정보 찾기.
# - 종목코드 : code
# - 시가총액 : market_cap(replace로 ,빼기)
# - 상장일 : reg_day
# - PER : per(소수점 두번째 자리까지)
# - kospi 여부

# %%
##### 업종별 이름, 사이트 다 모으기.

# 크롬드라이버가 연결되어 있는 주소 저장
chromedriver ='E:/big12/python-project/note/driver/chromedriver.exe'

# 크롬드라이버 연결
driver = webdriver.Chrome(chromedriver)

#업종 사이트 연결
driver.get('https://finance.naver.com/sise/sise_group.nhn?type=upjong')

#업종의 tbody에는 업종별로 사이트를 저장하는 a태그들이 있다. 그것을 꺼낸다.
a_tags = driver.find_element_by_tag_name('tbody').find_elements_by_tag_name('a')

category_list =[]

#업종의 주소와 이름을 저장
for a in a_tags:
    address = a.get_attribute('href')
    name = a.text
    
    if(name == '기타'):
        continue
    category_list.append([address,name])

#구글 드라이버를 꼭 닫아주기.
driver.close()

# %%
# 여기서부터 다시하기

# function 생성.
def add_category_info(name_website):
    #파라미터로 들어온 것은 [웹사이트,이름]으로 구성되어 있는 리스트 이다.
    #크롬드라이버 주소 저장
    chromedriver ='E:/big12/python-project/note/driver/chromedriver.exe'
    #크롬드라이버 object 생성
    driver = webdriver.Chrome(chromedriver)
    
    #웹사이트로 가기.
    driver.get(name_website[0])
    #특정업종사이트의 name_area의 a태그에는 종목의 주소와 이름이 저장되어있다.
    tmp = driver.find_elements_by_class_name('name_area')
    #종목 주소 저장
    address = [x.find_element_by_tag_name('a').get_attribute('href') for x in tmp]
    #종목 이름 저장
    name = [x.find_element_by_tag_name('a').text for x in tmp]
    
    #변수를 저장할 빈리스트
    code_list =[]
    market_cap_list =[]
    reg_day_list=[]
    per_list=[]
    kospi_list=[]
    name_list=[]
    
    #주소를 for문으로 돌린다.
    for addr in address:
        
        #드라이버로 1종목의 주소에 들어간다.
        driver.get(addr)
        #잠시대기
        time.sleep(0.5)
        
        
        #code라는 곳에는 업종코드가 저장
        code_list.append(driver.find_element_by_class_name('code').text)
        
        #wrap_companmy에 회사이름이 저장 되어 있따
        name_list.append(driver.find_element_by_class_name('wrap_company').find_element_by_tag_name('a').text)
        
        #_market_sum에는 시가총액이 들어가 있다.
        market_cap = driver.find_element_by_id('_market_sum').text
        
        #2가지 예외처리를 한다. 4조 9,222같은 경우에는 띄어쓰기를 기준으로 두개를 나누어주고 콤마를 제외하고 붙여야한다.
        if(market_cap.find('조')!=-1):
            tmp_list = market_cap.split(' ')
            market_cap = tmp_list[0][:-1]+tmp_list[1][:]
        if(market_cap.find(',')!=-1):
            market_cap = market_cap.replace(",","")
        
        #리스트에 저장해준다.    
        market_cap_list.append(int(market_cap))
        
        #per은 N/A인 경우가 있다. N/A인 경우는 해당 id 자체가 없기 때문에 try를 사용하여 except가 발생한다면 -1.0으로 대체한다.
        try:

            per = float(driver.find_element_by_id('_per').text)
        except:
            #na는 -1로 치환한다.
            per =-1.0
        finally:
            #어쨌든 저장
            per_list.append(per)
            
        #kospi라는 클래스가 있거나 kosdaq이라는 클래스가 있다. 어차피 둘 중 하나만 있기 때문에 
        #코스피 클래스가 없으면 코스닥으로 넘어간다.
        try:
            driver.find_element_by_class_name('kospi')
            kospi_list.append('kospi')
            
        except:
            kospi_list.append('kosdaq')

    #데이터프레임에 저장한다.
    df = pd.DataFrame(
        {
            'code' : code_list,
            'name' :name_list,
            'market_cap' : market_cap_list,
            'per' : per_list,
            'class' : kospi_list
        }
    )

    #상장일은 ajax처리가 되어 다른 사이트에 있다. 그 자료를 따로 받아주도록 하자.
    for code in code_list:
        #code_list에 저장되어 있는 것을 활용하여
        code= code
        
        #이 사이트에서 code만 바꾸어준다.
        reg_site = 'https://navercomp.wisereport.co.kr/v2/company/c1020001.aspx?cmp_cd={code}&cn='.format(code = code)
        
        #드라이버를 사용하여 해당사이트로 이동
        driver.get(reg_site)
        #상장일의 클래스는 클래스를 2개를 사용한다. c2 txt
        tmp_reg = driver.find_elements_by_class_name('c2.txt')[1].text
        
        #상장일이 좀 복잡하게 되어있던데 까먹었다. 이렇게 하면 되더라고요...
        reg_day_list.append(tmp_reg.split(' ')[2][:-1])
    
    
    #포문을 벗어나고 상장일을 df에 등록해준다.
    df['reg_day']=reg_day_list
    #코드에도 A를 추가해준다.(엑셀에서 숫자로 인식하여 0을 빼벌임)
    df['code'] = [ 'A'+x for x in df['code']]
    
    #업종의 이름으로 저장
    df.to_csv('./categories/'+name_website[1]+'.csv', encoding='utf-8')
    
    #꼭 닫아주기로 하자.
    driver.close()
    
    ###close와 open을 어디다 넣어줘야하는지 고민

# %%
## 리스트가 제대로 나왔나용
category_list
# Out:
# [['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=183',
#   '기타금융'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=219',
#   '레저용장비와제품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=231',
#   '사무용전자제품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=12',
#   '증권'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=218',
#   '생명과학도구및서비스'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=166',
#   '출판'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=201',
#   '교육서비스'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=164',
#   '판매업체'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=204',
#   '방송과엔터테인먼트'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=194',
#   '건강관리기술'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=20',
#   '은행'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=53',
#   '비철금속'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=217',
#   '석유와가스'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=221',
#   '전기제품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=35',
#   '제약'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=210',
#   '인터넷과카탈로그소매'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=134',
#   '섬유,의류,신발,호화품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=177',
#   '광고'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=200',
#   '가구'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=144',
#   '전기장비'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=191',
#   '복합기업'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=197',
#   '전자장비와기기'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=171',
#   '건축제품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=205',
#   '에너지장비및서비스'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=212',
#   '해운사'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=185',
#   '카드'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=36',
#   '자동차부품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=192',
#   '생명보험'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=38',
#   '식품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=168',
#   '가스유틸리티'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=193',
#   '복합유틸리티'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=176',
#   '전기유틸리티'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=146',
#   '생물공학'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=220',
#   '도로와철도운송'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=167',
#   '전문소매'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=187',
#   '항공사'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=109',
#   '창업투자'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=173',
#   '포장재'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=196',
#   '종이와목재'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=232',
#   '독립전력생산및에너지거래'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=211',
#   '건강관리장비와용품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=162',
#   '건축자재'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=62',
#   '철강'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=42',
#   '건설'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=138',
#   '기계'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=190',
#   '손해보험'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=227',
#   '식품과기본식료품소매'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=203',
#   '컴퓨터와주변기기'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=198',
#   '백화점과일반상점'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=140',
#   '화학'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=199',
#   '디스플레이장비및부품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=182',
#   '담배'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=214',
#   '가정용기기와용품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=226',
#   '무역회사와판매업체'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=136',
#   '통신장비'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=44',
#   '자동차'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=233',
#   '건강관리업체및서비스'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=229',
#   '부동산'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=184',
#   '무선통신서비스'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=189',
#   '운송인프라'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=208',
#   '상업서비스와공급품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=207',
#   '핸드셋'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=154',
#   'IT서비스'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=228',
#   '다각화된통신서비스'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=216',
#   '우주항공과국방'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=206',
#   '화장품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=202',
#   '반도체와반도체장비'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=174',
#   '가정용품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=213',
#   '전자제품'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=161',
#   '호텔,레스토랑,레저'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=235',
#   '게임엔터테인먼트'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=33',
#   '소프트웨어'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=145',
#   '음료'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=215',
#   '조선'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=234',
#   '항공화물운송과물류'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=222',
#   '디스플레이패널'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=236',
#   '양방향미디어와서비스'],
#  ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=230',
#   '문구류']]

# %%
###category_list에 인덱싱 지정하셔도 됩니당. Threading pool에 4번 연속 실행되는 function

def thread_run(sorted_list):

    for name_website in tqdm(sorted_list):
        add_category_info(name_website)

# %%
pd.read_csv('./categories/', encoding='utf-8')

# %% [markdown]
# ## 기타는 상장일이 없으니 빼주세용

# %%
from multiprocessing.pool import ThreadPool
#아 왜 안대냐귱
cat1=[]
cat2=[]
cat3=[]
cat4=[]

for i in range(len(category_list)):
    if i%4==0:
        cat1.append(category_list[i])
    elif i%4==1:
        cat2.append(category_list[i])
    elif i%4==2:
        cat3.append(category_list[i])
    elif i%4==3:
        cat4.append(category_list[i])    
print(len(cat1),cat1[1])

sorted_categories = [[cat1],[cat2],[cat3],[cat4]]

now1=datetime.now
with ThreadPool(4) as tp:
    tp.starmap(thread_run,sorted_categories)
now2=datetime.now

print(now2-now1)
# Out:
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/19 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/19 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
# 20 ['https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=218', '생명과학도구및서비스']
#   5%|████▎                                                                              | 1/19 [00:04<01:19,  4.44s/it]
#
#
#   5%|████▏                                                                              | 1/20 [00:15<04:46, 15.06s/it]
#
#
#  10%|████████▎                                                                          | 2/20 [00:22<03:17, 10.96s/it]
#  11%|████████▋                                                                          | 2/19 [00:33<05:19, 18.77s/it]
#
#
#  15%|████████████▍                                                                      | 3/20 [00:38<03:41, 13.02s/it]
#
#   5%|████▎                                                                              | 1/19 [00:49<14:53, 49.66s/it]
#  10%|████████▎                                                                          | 2/20 [00:55<09:02, 30.15s/it]
#
#  11%|████████▋                                                                          | 2/19 [01:02<07:54, 27.90s/it]
#
#
#  20%|████████████████▌                                                                  | 4/20 [01:30<07:38, 28.67s/it]
#
#  16%|█████████████                                                                      | 3/19 [01:50<09:55, 37.24s/it]
#
#
#  15%|████████████▍                                                                      | 3/20 [02:10<14:15, 50.32s/it]
#
#  21%|█████████████████▍                                                                 | 4/19 [02:12<07:46, 31.08s/it]
#
#  26%|█████████████████████▊                                                             | 5/19 [02:48<07:41, 32.94s/it]
#
#  20%|████████████████▌                                                                  | 4/20 [03:08<14:15, 53.45s/it]
#
#  37%|██████████████████████████████▌                                                    | 7/19 [03:20<04:40, 23.37s/it]
#
#  42%|██████████████████████████████████▉                                                | 8/19 [03:28<03:23, 18.52s/it]
#
#
#  30%|████████████████████████▉                                                          | 6/20 [03:48<13:13, 56.70s/it]
#
#  47%|███████████████████████████████████████▎                                           | 9/19 [03:50<03:16, 19.65s/it]
#
#
#  35%|█████████████████████████████                                                      | 7/20 [03:52<08:35, 39.66s/it]
#
#  53%|███████████████████████████████████████████▏                                      | 10/19 [03:58<02:22, 15.78s/it]
#  21%|█████████████████▍                                                                 | 4/19 [04:00<21:30, 86.04s/it]
#
#
#  40%|█████████████████████████████████▏                                                 | 8/20 [04:15<06:49, 34.15s/it]
#  26%|█████████████████████▊                                                             | 5/19 [04:16<14:07, 60.54s/it]
#
#
#  45%|█████████████████████████████████████▎                                             | 9/20 [04:28<05:03, 27.61s/it]
#  32%|██████████████████████████▏                                                        | 6/19 [04:40<10:26, 48.16s/it]
#
#
#  30%|████████████████████████▉                                                          | 6/20 [05:30<13:46, 59.06s/it]
#
#  35%|█████████████████████████████                                                      | 7/20 [05:45<09:40, 44.65s/it]
#
#  63%|███████████████████████████████████████████████████▊                              | 12/19 [06:00<04:14, 36.29s/it]
#
#  68%|████████████████████████████████████████████████████████                          | 13/19 [06:04<02:39, 26.56s/it]
#
#
#  55%|█████████████████████████████████████████████                                     | 11/20 [06:16<06:27, 43.08s/it]
#
#  74%|████████████████████████████████████████████████████████████▍                     | 14/19 [06:18<01:54, 22.80s/it]
#
#  79%|████████████████████████████████████████████████████████████████▋                 | 15/19 [06:27<01:14, 18.66s/it]
#
#  84%|█████████████████████████████████████████████████████████████████████             | 16/19 [06:35<00:46, 15.40s/it]
#
#  89%|█████████████████████████████████████████████████████████████████████████▎        | 17/19 [06:47<00:28, 14.35s/it]
#
#
#  40%|█████████████████████████████████▏                                                 | 8/20 [07:32<12:53, 64.44s/it]
#  37%|██████████████████████████████▌                                                    | 7/19 [07:49<18:50, 94.23s/it]
#
#  95%|█████████████████████████████████████████████████████████████████████████████▋    | 18/19 [07:55<00:30, 30.55s/it]
#  42%|██████████████████████████████████▉                                                | 8/19 [07:55<12:08, 66.27s/it]
#  47%|███████████████████████████████████████▎                                           | 9/19 [08:04<08:02, 48.30s/it]
#
# 100%|██████████████████████████████████████████████████████████████████████████████████| 19/19 [08:05<00:00, 25.53s/it]
#
#  45%|█████████████████████████████████████▎                                             | 9/20 [08:39<11:56, 65.16s/it]
#
#
#  65%|█████████████████████████████████████████████████████▎                            | 13/20 [09:10<08:16, 70.90s/it]
#
#
#  70%|█████████████████████████████████████████████████████████▍                        | 14/20 [09:20<05:14, 52.47s/it]
#  58%|███████████████████████████████████████████████▍                                  | 11/19 [09:28<06:16, 47.07s/it]
#
#
#  75%|█████████████████████████████████████████████████████████████▌                    | 15/20 [09:43<03:37, 43.42s/it]
#  50%|█████████████████████████████████████████                                         | 10/20 [10:04<11:53, 71.36s/it]
#
#
#  55%|█████████████████████████████████████████████                                     | 11/20 [11:23<11:02, 73.57s/it]
#  68%|████████████████████████████████████████████████████████                          | 13/19 [11:42<06:12, 62.03s/it]
#
#
#  85%|█████████████████████████████████████████████████████████████████████▋            | 17/20 [12:13<02:56, 58.70s/it]
#  74%|████████████████████████████████████████████████████████████▍                     | 14/19 [12:39<05:01, 60.37s/it]
#
#
#  90%|█████████████████████████████████████████████████████████████████████████▊        | 18/20 [12:40<01:38, 49.27s/it]
#  79%|████████████████████████████████████████████████████████████████▋                 | 15/19 [12:51<03:02, 45.66s/it]
#
#
#  95%|█████████████████████████████████████████████████████████████████████████████▉    | 19/20 [13:10<00:43, 43.50s/it]
#
#
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [13:17<00:00, 39.87s/it]
#  75%|█████████████████████████████████████████████████████████████▌                    | 15/20 [14:10<03:16, 39.35s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [16:24<00:00, 49.25s/it]
#
#  89%|████████████████████████████████████████████████████████████████████████▍        | 17/19 [17:39<03:22, 101.27s/it]
#  95%|█████████████████████████████████████████████████████████████████████████████▋    | 18/19 [18:19<01:23, 83.05s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 19/19 [18:39<00:00, 58.95s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-953f0a423885> in <module>
#      24 now2=datetime.now
#      25
# ---> 26 print(now2-now1)
#
# TypeError: unsupported operand type(s) for -: 'builtin_function_or_method' and 'builtin_function_or_method'
